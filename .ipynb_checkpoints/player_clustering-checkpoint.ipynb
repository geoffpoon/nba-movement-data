# %%
import numpy as np
import scipy
import pandas as pd

# %%
import pickle
import copy

def save_obj(obj, name ):
    with open(name, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name, 'rb') as f:
        return pickle.load(f)
    
    
nmf_dict = load_obj('nmf_dict.pkl')

# %%
nmf_dict.keys()
# Out:
# dict_keys(['LL', 'LL_norm', 'H_att10_norm', 'W_att10_norm', 'H_made10_norm', 'W_made10_norm', 'H_att16_norm', 'W_att16_norm', 'H_made16_norm', 'W_made16_norm', 'H_att20_norm', 'W_att20_norm', 'H_made20_norm', 'W_made20_norm', 'unique_players', 'list_of_playerSeason', 'X', 'Y'])

# %%
W_att = nmf_dict['W_att16_norm']
W_att.shape
# Out:
# (2400, 16)

# %%
LL_att = nmf_dict['LL']['SHOT_ATTEMPTED_FLAG']
W_att_norm = W_att.copy()
tot_shots = LL_att.sum(axis=1)
for i in range(len(W_att)):
    W_att_norm[i,:] = W_att[i,:] / tot_shots[i]

# %%
df_Watt = pd.DataFrame(W_att_norm, columns=["Basis %d"%i for i in range(16)])
df_Watt.describe()
# Out:
#            Basis 0      Basis 1      Basis 2      Basis 3      Basis 4  \
# count  2400.000000  2400.000000  2400.000000  2400.000000  2400.000000
# mean      0.121183     0.086917     0.036421     0.088570     0.039833
# std       0.103287     0.067733     0.048162     0.086289     0.041409
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.051330     0.037596     0.000638     0.029617     0.008172
# 50%       0.095602     0.073994     0.019283     0.064824     0.029200
# 75%       0.159333     0.123551     0.050912     0.118564     0.057295
# max       0.743221     0.414833     0.451936     0.687572     0.251445
#
#            Basis 5      Basis 6      Basis 7      Basis 8      Basis 9  \
# count  2400.000000  2400.000000  2400.000000  2400.000000  2400.000000
# mean      0.051689     0.062321     0.033000     0.081470     0.035081
# std       0.053186     0.079052     0.042739     0.081673     0.042596
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.013025     0.001748     0.000413     0.020455     0.003819
# 50%       0.037732     0.032030     0.018856     0.059013     0.022537
# 75%       0.074374     0.095040     0.045910     0.118484     0.049575
# max       0.470643     0.584858     0.397744     0.563393     0.357003
#
#           Basis 10     Basis 11     Basis 12     Basis 13     Basis 14  \
# count  2400.000000  2400.000000  2400.000000  2400.000000  2400.000000
# mean      0.060727     0.077661     0.068630     0.051166     0.057908
# std       0.065621     0.080896     0.071381     0.056877     0.055970
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.013581     0.000775     0.004230     0.005039     0.014689
# 50%       0.041709     0.058526     0.050598     0.033986     0.043722
# 75%       0.086063     0.127116     0.109725     0.077872     0.084854
# max       0.534779     0.516578     0.410285     0.444342     0.464471
#
#           Basis 15
# count  2400.000000
# mean      0.047424
# std       0.058639
# min       0.000000
# 25%       0.001046
# 50%       0.027974
# 75%       0.071121
# max       0.408888

# %%
df_Watt_meannorm = df_Watt.copy()
for col in df_Watt_meannorm.columns:
    df_Watt_meannorm.loc[:,col] = (df_Watt_meannorm.loc[:,col] - df_Watt_meannorm[col].mean()) / (df_Watt_meannorm[col].max() - df_Watt_meannorm[col].min())
df_Watt_meannorm.describe()
# Out:
#             Basis 0       Basis 1       Basis 2       Basis 3       Basis 4  \
# count  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03
# mean   3.080117e-16  3.747407e-16 -5.831562e-17  3.648268e-16 -2.997833e-16
# std    1.389722e-01  1.632770e-01  1.065686e-01  1.254988e-01  1.646859e-01
# min   -1.630505e-01 -2.095223e-01 -8.058789e-02 -1.288151e-01 -1.584166e-01
# 25%   -9.398621e-02 -1.188927e-01 -7.917599e-02 -8.574064e-02 -1.259147e-01
# 50%   -3.441823e-02 -3.115176e-02 -3.791940e-02 -3.453588e-02 -4.228952e-02
# 75%    5.133180e-02  8.831091e-02  3.206636e-02  4.362411e-02  6.944808e-02
# max    8.369495e-01  7.904777e-01  9.194121e-01  8.711849e-01  8.415834e-01
#
#             Basis 5       Basis 6       Basis 7       Basis 8       Basis 9  \
# count  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03
# mean   2.575927e-16 -1.409405e-16 -2.970772e-16 -1.489260e-17  7.665165e-17
# std    1.130075e-01  1.351648e-01  1.074534e-01  1.449660e-01  1.193164e-01
# min   -1.098259e-01 -1.065583e-01 -8.296794e-02 -1.446061e-01 -9.826598e-02
# 25%   -8.215101e-02 -1.035702e-01 -8.193056e-02 -1.082996e-01 -8.756882e-02
# 50%   -2.965465e-02 -5.179282e-02 -3.555970e-02 -3.986114e-02 -3.513684e-02
# 75%    4.820039e-02  5.594244e-02  3.245798e-02  6.569837e-02  4.059734e-02
# max    8.901741e-01  8.934417e-01  9.170321e-01  8.553939e-01  9.017340e-01
#
#            Basis 10      Basis 11      Basis 12      Basis 13      Basis 14  \
# count  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03  2.400000e+03
# mean   2.522924e-16 -6.248474e-17 -1.212572e-16  6.614501e-17  4.494669e-17
# std    1.227070e-01  1.565988e-01  1.739778e-01  1.280032e-01  1.205026e-01
# min   -1.135558e-01 -1.503366e-01 -1.672746e-01 -1.151501e-01 -1.246745e-01
# 25%   -8.816019e-02 -1.488368e-01 -1.569659e-01 -1.038092e-01 -9.304882e-02
# 50%   -3.556369e-02 -3.704065e-02 -4.395082e-02 -3.866274e-02 -3.054254e-02
# 75%    4.737668e-02  9.573618e-02  1.001613e-01  6.010144e-02  5.801565e-02
# max    8.864442e-01  8.496634e-01  8.327254e-01  8.848499e-01  8.753255e-01
#
#            Basis 15
# count  2.400000e+03
# mean  -1.401021e-16
# std    1.434104e-01
# min   -1.159829e-01
# 25%   -1.134250e-01
# 50%   -4.756692e-02
# 75%    5.795379e-02
# max    8.840171e-01

# %%
import sklearn.metrics.pairwise

dist_mat = 1. - sklearn.metrics.pairwise.cosine_similarity(df_Watt_meannorm)
dist_mat
# Out:
# array([[-2.22044605e-16,  1.18653196e+00,  1.05387830e+00, ...,
#          1.04395563e+00,  7.88302470e-01,  1.12570379e+00],
#        [ 1.18653196e+00,  3.33066907e-16,  5.51173713e-01, ...,
#          7.72729588e-01,  1.51902048e+00,  1.37682470e+00],
#        [ 1.05387830e+00,  5.51173713e-01,  2.22044605e-16, ...,
#          8.29257506e-01,  1.02700694e+00,  1.17796725e+00],
#        ...,
#        [ 1.04395563e+00,  7.72729588e-01,  8.29257506e-01, ...,
#          0.00000000e+00,  1.36082695e+00,  1.20237122e+00],
#        [ 7.88302470e-01,  1.51902048e+00,  1.02700694e+00, ...,
#          1.36082695e+00,  1.11022302e-16,  3.51231891e-01],
#        [ 1.12570379e+00,  1.37682470e+00,  1.17796725e+00, ...,
#          1.20237122e+00,  3.51231891e-01,  2.22044605e-16]])

# %%
np.max(dist_mat)
# Out:
# 1.9402739805481204

# %%
import matplotlib.pyplot as plt

fig= plt.figure(figsize=(8,8))
im = plt.imshow(dist_mat,cmap='jet')
plt.colorbar(im,fraction=0.046, pad=0.04)
plt.show()

# %%
import scipy.cluster.hierarchy

fig = plt.figure(figsize=(10,10))

# Compute and plot dendrogram.
ax2 = fig.add_axes([0.3,0.71,0.6,0.2])
Y = scipy.cluster.hierarchy.linkage(dist_mat, method='ward')
Z1 = scipy.cluster.hierarchy.dendrogram(Y,color_threshold = 1.45)
ax2.set_xticks([])
ax2.set_yticks([])

# Plot distance matrix.
axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
idx1 = Z1['leaves']
dist_mat = dist_mat[idx1,:]
dist_mat = dist_mat[:,idx1]
im = axmatrix.matshow(dist_mat, aspect='auto', origin='lower',cmap='jet')
axmatrix.set_xticks([])
axmatrix.set_yticks([])

# Plot colorbar.
axcolor = fig.add_axes([0.91,0.1,0.02,0.6])
plt.colorbar(im, cax=axcolor)
