# %%
import requests
import pandas as pd
import sys

# %%
# Requesting Player ID (or PERSON_ID) from stats.nba.com API
# so that we can easily find data regarding a specific player.
# We can only pull data based on a player's unique ID#, not their name

PARAMS = {'LeagueID': '00', 
          'Season': '2013-18',
          'IsOnlyCurrentSeason': '0',
         }

# set headers, otherwise the API might not work
HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'),
           'referer': 'http://stats.nba.com/scores/'
          }


# NOTE: This API is not documented well and is poorly maintained. 
# Let's hope they don't change the endpoints and/or required parameters
r = requests.get('http://stats.nba.com/stats/commonallplayers', 
                 params=PARAMS, headers=HEADERS)


# And let's organize this data into a nice Pandas data frame

playerInfo_json_headers = r.json()['resultSets'][0]['headers']
playerInfo_json_content = r.json()['resultSets'][0]['rowSet']

playerInfo_df = pd.DataFrame(playerInfo_json_content, columns=playerInfo_json_headers)

# And just to show this is working, we can see some of the players who came into the
# league in 2013-14 season when tracking cameras were first installed
playerInfo_df[playerInfo_df.FROM_YEAR == '2013'].head()
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST     DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 20      203500            Adams, Steven           Steven Adams             1
# 99      203507   Antetokounmpo, Giannis  Giannis Antetokounmpo             1
# 104     203544              Antic, Pero             Pero Antic             1
# 152     203569              Babb, Chris             Chris Babb             1
# 271     203461         Bennett, Anthony        Anthony Bennett             1
#
#     FROM_YEAR TO_YEAR             PLAYERCODE     TEAM_ID      TEAM_CITY  \
# 20       2013    2017           steven_adams  1610612760  Oklahoma City
# 99       2013    2017  giannis_antetokounmpo  1610612749      Milwaukee
# 104      2013    2014             pero_antic  1610612737        Atlanta
# 152      2013    2014             chris_babb  1610612738         Boston
# 271      2013    2016        anthony_bennett  1610612739      Cleveland
#
#      TEAM_NAME TEAM_ABBREVIATION  TEAM_CODE GAMES_PLAYED_FLAG
# 20     Thunder               OKC    thunder                 Y
# 99       Bucks               MIL      bucks                 Y
# 104      Hawks               ATL      hawks                 Y
# 152    Celtics               BOS    celtics                 Y
# 271  Cavaliers               CLE  cavaliers                 Y

# %%
player_id = int(playerInfo_df[playerInfo_df.DISPLAY_FIRST_LAST == 'Stephen Curry'].PERSON_ID)
playerInfo_df[playerInfo_df.PERSON_ID == player_id]
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 817     201939           Curry, Stephen      Stephen Curry             1
#
#     FROM_YEAR TO_YEAR     PLAYERCODE     TEAM_ID     TEAM_CITY TEAM_NAME  \
# 817      2009    2017  stephen_curry  1610612744  Golden State  Warriors
#
#     TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG
# 817               GSW  warriors                 Y

# %%
# player_id=0 : not specifying PLAYER shooting
# team_id=0 : not specifying TEAM of shooter
# opp_team_id=0 : not specifying OPPOSING TEAM

player_name = ''
if player_name in playerInfo_df.DISPLAY_FIRST_LAST:
    player_id = int(playerInfo_df[playerInfo_df.DISPLAY_FIRST_LAST == player_name].PERSON_ID)
else:
    player_id = 0
team_id = 0
opp_team_id = 0
season = 2004

# game_id='' : not specifying GAME ID
# season_type : either 'Regular Season', 'Playoffs', 'Pre Season', or 'All Star'
game_id = ''
season_type = 'Regular Season'


#########################################

season_string = str(season) + '-' + str(season+1)[2:]

PARAMS = {'Period': 0, 
          'VsConference': '', 
          'LeagueID': '00', 
          'LastNGames': '0', 
          'TeamID': str(team_id), 
          'Position': '', 
          'Location': '',
          'Outcome': '',
          'ContextMeasure': 'FGA',
          'DateFrom': '',
          'StartPeriod': '',
          'DateTo': '',
          'OpponentTeamID': str(opp_team_id),
          'ContextFilter': '',
          'RangeType': '',
          'Season': season_string,
          'AheadBehind': '',
          'PlayerID': str(player_id),
          'EndRange': '',
          'VsDivision': '',
          'PointDiff': '',
          'RookieYear': '',
          'GameSegment': '',
          'Month': '0',
          'ClutchTime': '',
          'StartRange': '',
          'EndPeriod': '',
          'SeasonType': season_type,
          'SeasonSegment': '',
          'GameID': str(game_id),
          'PlayerPosition': ''
         }

# set headers, otherwise the API might not work
HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'),
           'referer': 'http://stats.nba.com/scores/'
          }



# Requesting data from stats.nba.com with the endpoint /stats/shotchartdetail
# This gives us information on the matchup, game situtation, and xy-location
# of every shot that we requested (falls under our filters)


# NOTE: This API is not documented well and is poorly maintained. 
# Let's hope they don't change the endpoints and/or required parameters
r = requests.get('http://stats.nba.com/stats/shotchartdetail', 
                 params=PARAMS, headers=HEADERS)

# %%
# We split the API response into headers and content
json_allStuff = r.json()
json_headers = json_allStuff['resultSets'][0]['headers']
json_content = json_allStuff['resultSets'][0]['rowSet']


shots_df = pd.DataFrame(json_content, columns=json_headers)

import json
with open('shots_data_%s.json'%season_string, 'w') as outfile:
    json.dump(json_allStuff, outfile)

shots_df
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0020400001              2       1888
# 1       Shot Chart Detail  0020400001              5       2419
# 2       Shot Chart Detail  0020400001              7       2397
# 3       Shot Chart Detail  0020400001              9       1112
# 4       Shot Chart Detail  0020400001             10       2397
# 5       Shot Chart Detail  0020400001             11        739
# 6       Shot Chart Detail  0020400001             13       1508
# 7       Shot Chart Detail  0020400001             16       2397
# 8       Shot Chart Detail  0020400001             18       1112
# 9       Shot Chart Detail  0020400001             21        754
# 10      Shot Chart Detail  0020400001             24        739
# 11      Shot Chart Detail  0020400001             26       1508
# 12      Shot Chart Detail  0020400001             28       1888
# 13      Shot Chart Detail  0020400001             30       1503
# 14      Shot Chart Detail  0020400001             32       1503
# 15      Shot Chart Detail  0020400001             33        739
# 16      Shot Chart Detail  0020400001             34        754
# 17      Shot Chart Detail  0020400001             36       1508
# 18      Shot Chart Detail  0020400001             38       1888
# 19      Shot Chart Detail  0020400001             40       1497
# 20      Shot Chart Detail  0020400001             43       1503
# 21      Shot Chart Detail  0020400001             46       1508
# 22      Shot Chart Detail  0020400001             49        369
# 23      Shot Chart Detail  0020400001             50       1497
# 24      Shot Chart Detail  0020400001             53       1503
# 25      Shot Chart Detail  0020400001             56       1888
# 26      Shot Chart Detail  0020400001             68        754
# 27      Shot Chart Detail  0020400001             67       1888
# 28      Shot Chart Detail  0020400001             83       1508
# 29      Shot Chart Detail  0020400001             89       1497
# ...                   ...         ...            ...        ...
# 197592  Shot Chart Detail  0020401230            406       1517
# 197593  Shot Chart Detail  0020401230            407        754
# 197594  Shot Chart Detail  0020401230            411       2047
# 197595  Shot Chart Detail  0020401230            412        731
# 197596  Shot Chart Detail  0020401230            414        754
# 197597  Shot Chart Detail  0020401230            419       2755
# 197598  Shot Chart Detail  0020401230            420       2047
# 197599  Shot Chart Detail  0020401230            421       2755
# 197600  Shot Chart Detail  0020401230            422       2047
# 197601  Shot Chart Detail  0020401230            424        722
# 197602  Shot Chart Detail  0020401230            425       2207
# 197603  Shot Chart Detail  0020401230            427       2755
# 197604  Shot Chart Detail  0020401230            429       2047
# 197605  Shot Chart Detail  0020401230            432       2571
# 197606  Shot Chart Detail  0020401230            438        722
# 197607  Shot Chart Detail  0020401230            439        731
# 197608  Shot Chart Detail  0020401230            442        731
# 197609  Shot Chart Detail  0020401230            444        754
# 197610  Shot Chart Detail  0020401230            445       2067
# 197611  Shot Chart Detail  0020401230            446       2047
# 197612  Shot Chart Detail  0020401230            448        731
# 197613  Shot Chart Detail  0020401230            454        754
# 197614  Shot Chart Detail  0020401230            457       2845
# 197615  Shot Chart Detail  0020401230            458       2571
# 197616  Shot Chart Detail  0020401230            460       2067
# 197617  Shot Chart Detail  0020401230            462       2230
# 197618  Shot Chart Detail  0020401230            464        754
# 197619  Shot Chart Detail  0020401230            466       2230
# 197620  Shot Chart Detail  0020401230            470       2321
# 197621  Shot Chart Detail  0020401230            475       2047
#
#                PLAYER_NAME     TEAM_ID         TEAM_NAME  PERIOD  \
# 0         Richard Hamilton  1610612765   Detroit Pistons       1
# 1          Tayshaun Prince  1610612765   Detroit Pistons       1
# 2                 Yao Ming  1610612745   Houston Rockets       1
# 3              Ben Wallace  1610612765   Detroit Pistons       1
# 4                 Yao Ming  1610612745   Houston Rockets       1
# 5          Rasheed Wallace  1610612765   Detroit Pistons       1
# 6           Maurice Taylor  1610612745   Houston Rockets       1
# 7                 Yao Ming  1610612745   Houston Rockets       1
# 8              Ben Wallace  1610612765   Detroit Pistons       1
# 9              Jim Jackson  1610612745   Houston Rockets       1
# 10         Rasheed Wallace  1610612765   Detroit Pistons       1
# 11          Maurice Taylor  1610612745   Houston Rockets       1
# 12        Richard Hamilton  1610612765   Detroit Pistons       1
# 13           Tracy McGrady  1610612745   Houston Rockets       1
# 14           Tracy McGrady  1610612745   Houston Rockets       1
# 15         Rasheed Wallace  1610612765   Detroit Pistons       1
# 16             Jim Jackson  1610612745   Houston Rockets       1
# 8                       9                 18 ...               Center(C)
# 9                       8                 56 ...   Right Side Center(RC)
# 10                      8                 44 ...               Center(C)
# 11                      8                 27 ...               Center(C)
# 12                      8                 17 ...               Center(C)
# 13                      8                  3 ...   Right Side Center(RC)
# 14                      7                 45 ...               Center(C)
# 15                      7                 21 ...           Right Side(R)
# 16                      6                 58 ...           Right Side(R)
# 17                      6                 52 ...               Center(C)
# 18                      6                 46 ...               Center(C)
# 19                      6                 33 ...   Right Side Center(RC)
# 20                      6                  8 ...            Left Side(L)
# 21                      6                  1 ...               Center(C)
# 22                      5                 28 ...               Center(C)
# 23                      5                 10 ...            Left Side(L)
# 24                      4                 54 ...               Center(C)
# 25                      4                 37 ...            Left Side(L)
# 26                      3                 48 ...   Right Side Center(RC)
# 27                      3                 28 ...               Center(C)
# 28                      2                 43 ...    Left Side Center(LC)
# 29                      2                 23 ...    Left Side Center(LC)
# ...                   ...                ... ...                     ...
# 197592                  7                  6 ...           Right Side(R)
# 197593                  6                 54 ...    Left Side Center(LC)
# 197594                  6                 38 ...    Left Side Center(LC)
# 197595                  6                 21 ...               Center(C)
# 197596                  6                 14 ...               Center(C)
# 197597                  5                 55 ...               Center(C)
# 197598                  5                 41 ...   Right Side Center(RC)
# 197599                  5                 20 ...               Center(C)
# 197600                  5                  6 ...               Center(C)
# 197601                  4                 48 ...               Center(C)
# 197602                  4                 34 ...           Right Side(R)
# 197603                  4                 25 ...           Right Side(R)
# 197604                  4                 15 ...               Center(C)
# 197605                  4                  0 ...            Left Side(L)
# 197606                  3                 32 ...    Left Side Center(LC)
# 197607                  3                 30 ...               Center(C)
# 197608                  3                 28 ...               Center(C)
# 197609                  3                 15 ...            Left Side(L)
# 197610                  2                 57 ...           Right Side(R)
# 197611                  2                 47 ...    Left Side Center(LC)
# 197612                  2                 24 ...               Center(C)
# 197613                  2                  4 ...    Left Side Center(LC)
# 197614                  1                 47 ...               Center(C)
# 197615                  1                 39 ...    Left Side Center(LC)
# 197616                  1                 24 ...               Center(C)
# 197617                  1                 12 ...               Center(C)
# 197618                  1                  0 ...           Right Side(R)
# 197619                  0                 53 ...               Center(C)
# 197620                  0                 36 ...           Right Side(R)
# 197621                  0                 17 ...   Right Side Center(RC)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0              8-16 ft.            14  -149     3                   1
# 1              8-16 ft.             8     0    82                   1
# 2              8-16 ft.            14   140    46                   1
# 3             16-24 ft.            18  -161    82                   1
# 4       Less Than 8 ft.             0     0     0                   1
# 5              8-16 ft.            14   131    69                   1
# 6             16-24 ft.            17   149    86                   1
# 7              8-16 ft.            14  -138    41                   1
# 8       Less Than 8 ft.             0     0     0                   1
# 9             16-24 ft.            17    89   150                   1
# 10              24+ ft.            26    72   258                   1
# 11      Less Than 8 ft.             0     0     0                   1
# 12             8-16 ft.            12   -49   112                   1
# 13            16-24 ft.            17    87   155                   1
# 14      Less Than 8 ft.             0     0     0                   1
# 15             8-16 ft.             9    67    63                   1
# 26                   1   20041102  DET  HOU
# 27                   1   20041102  DET  HOU
# 28                   0   20041102  DET  HOU
# 29                   0   20041102  DET  HOU
# ...                ...        ...  ...  ...
# 197592               1   20050420  SAC  PHX
# 197593               0   20050420  SAC  PHX
# 197594               1   20050420  SAC  PHX
# 197595               0   20050420  SAC  PHX
# 197596               0   20050420  SAC  PHX
# 197597               1   20050420  SAC  PHX
# 197598               1   20050420  SAC  PHX
# 197599               1   20050420  SAC  PHX
# 197600               0   20050420  SAC  PHX
# 197601               1   20050420  SAC  PHX
# 197602               0   20050420  SAC  PHX
# 197603               0   20050420  SAC  PHX
# 197604               0   20050420  SAC  PHX
# 197605               1   20050420  SAC  PHX
# 197606               0   20050420  SAC  PHX
# 197607               0   20050420  SAC  PHX
# 197608               0   20050420  SAC  PHX
# 197609               1   20050420  SAC  PHX
# 197610               1   20050420  SAC  PHX
# 197611               0   20050420  SAC  PHX
# 197612               1   20050420  SAC  PHX
# 197613               0   20050420  SAC  PHX
# 197614               1   20050420  SAC  PHX
# 197615               1   20050420  SAC  PHX
# 197616               0   20050420  SAC  PHX
# 197617               0   20050420  SAC  PHX
# 197618               0   20050420  SAC  PHX
# 197619               1   20050420  SAC  PHX
# 197620               0   20050420  SAC  PHX
# 197621               0   20050420  SAC  PHX
#
# [197622 rows x 24 columns]

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# We do the same for the league avg data that bins the information for each zone
leagueAvg_json_headers = json_allStuff['resultSets'][1]['headers']
leagueAvg_json_content = json_allStuff['resultSets'][1]['rowSet']


leagueAvg_df = pd.DataFrame(leagueAvg_json_content, columns=leagueAvg_json_headers)
leagueAvg_df
# Out:
#           GRID_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 0   League Averages      Above the Break 3         Back Court(BC)
# 1   League Averages      Above the Break 3              Center(C)
# 2   League Averages      Above the Break 3   Left Side Center(LC)
# 3   League Averages      Above the Break 3  Right Side Center(RC)
# 4   League Averages              Backcourt         Back Court(BC)
# 5   League Averages  In The Paint (Non-RA)              Center(C)
# 6   League Averages  In The Paint (Non-RA)              Center(C)
# 7   League Averages  In The Paint (Non-RA)           Left Side(L)
# 8   League Averages  In The Paint (Non-RA)          Right Side(R)
# 9   League Averages          Left Corner 3           Left Side(L)
# 10  League Averages              Mid-Range              Center(C)
# 11  League Averages              Mid-Range              Center(C)
# 12  League Averages              Mid-Range   Left Side Center(LC)
# 13  League Averages              Mid-Range           Left Side(L)
# 14  League Averages              Mid-Range           Left Side(L)
# 15  League Averages              Mid-Range  Right Side Center(RC)
# 16  League Averages              Mid-Range          Right Side(R)
# 17  League Averages              Mid-Range          Right Side(R)
# 18  League Averages        Restricted Area              Center(C)
# 19  League Averages         Right Corner 3          Right Side(R)
#
#     SHOT_ZONE_RANGE    FGA    FGM  FG_PCT
# 0   Back Court Shot     25      1   0.040
# 1           24+ ft.   7425   2669   0.359
# 2           24+ ft.   9928   3586   0.361
# 3           24+ ft.   9297   3289   0.354
# 4   Back Court Shot    257      3   0.012
# 5          8-16 ft.   5542   2302   0.415
# 6   Less Than 8 ft.   8420   3219   0.382
# 7          8-16 ft.    934    376   0.403
# 8          8-16 ft.    903    355   0.393
# 9           24+ ft.   3945   1522   0.386
# 10         8-16 ft.   1202    513   0.427
# 11        16-24 ft.   3557   1452   0.408
# 12        16-24 ft.   3272   1336   0.408
# 13        16-24 ft.   1256    522   0.416
# 14         8-16 ft.   3173   1236   0.390
# 15        16-24 ft.   3432   1329   0.387
# 16        16-24 ft.   1120    424   0.379
# 17         8-16 ft.   3012   1217   0.404
# 18  Less Than 8 ft.  32435  20385   0.628
# 19          24+ ft.   3575   1441   0.403

# %%
# NOTE: we set player_id earlier

# per_mode : either 'Totals', 'PerGame', or 'Per36'
per_mode = 'PerGame'

#########################################

PARAMS = {'PerMode': per_mode, 
          'PlayerID': str(player_id),
         }

# set headers, otherwise the API might not work
HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'),
           'referer': 'http://stats.nba.com/scores/'
          }



# Requesting data from stats.nba.com with the endpoint /stats/shotchartdetail
# This gives us information on the matchup, game situtation, and xy-location
# of every shot that we requested (falls under our filters)


# NOTE: This API is not documented well and is poorly maintained. 
# Let's hope they don't change the endpoints and/or required parameters
r = requests.get('http://stats.nba.com/stats/playercareerstats', 
                 params=PARAMS, headers=HEADERS)

json_allStuff = r.json()
json_headers = json_allStuff['resultSets'][0]['headers']
json_content = json_allStuff['resultSets'][0]['rowSet']


careerStat_df = pd.DataFrame(json_content, columns=json_headers)
careerStat_df.drop(['PLAYER_ID', 'LEAGUE_ID', 'TEAM_ID', 'PLAYER_AGE', 
                    'GS', 'FGM', 'FG3M', 'FTM'], axis=1)[-5:]
# Out:
#   SEASON_ID TEAM_ABBREVIATION  GP   MIN   FGA  FG_PCT  FG3A  FG3_PCT  FTA  \
# 4   2013-14               GSW  78  36.5  17.7   0.471   7.9    0.424  4.5
# 5   2014-15               GSW  80  32.7  16.8   0.487   8.1    0.443  4.2
# 6   2015-16               GSW  79  34.2  20.2   0.504  11.2    0.454  5.1
# 7   2016-17               GSW  79  33.4  18.3   0.468  10.0    0.411  4.6
# 8   2017-18               GSW  28  32.5  17.9   0.492  10.0    0.414  6.7
#
#    FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF   PTS
# 4   0.885   0.6   3.7  4.3  8.5  1.6  0.2  3.8  2.5  24.0
# 5   0.914   0.7   3.6  4.3  7.7  2.0  0.2  3.1  2.0  23.8
# 6   0.908   0.9   4.6  5.4  6.7  2.1  0.2  3.3  2.0  30.1
# 7   0.898   0.8   3.7  4.5  6.6  1.8  0.2  3.0  2.3  25.3
# 8   0.926   0.6   4.5  5.2  6.4  1.7  0.1  2.9  2.4  27.9

# %%
# NOTE: we set player_id earlier

# game_id='' : not specifying GAME ID
# season_type : either 'Regular Season', 'Playoffs', 'Pre Season', or 'All Star'
game_id = ''
season = 2017
season_type = 'Regular Season'

# per_mode : either 'Totals', 'PerGame', or 'Per36'
per_mode = 'PerGame'

#########################################

season_string = str(season) + '-' + str(season+1)[2:]

PARAMS = {'PlayerID': str(player_id)
         }

# set headers, otherwise the API might not work
HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'),
           'referer': 'http://stats.nba.com/scores/'
          }



# Requesting data from stats.nba.com with the endpoint /stats/shotchartdetail
# This gives us information on the matchup, game situtation, and xy-location
# of every shot that we requested (falls under our filters)


# NOTE: This API is not documented well and is poorly maintained. 
# Let's hope they don't change the endpoints and/or required parameters
r = requests.get('http://stats.nba.com/stats/commonplayerinfo', 
                 params=PARAMS, headers=HEADERS)

bio_json_allStuff = r.json()
bio_json_headers = json_allStuff['resultSets'][0]['headers']
bio_json_content = json_allStuff['resultSets'][0]['rowSet']


bio_df = pd.DataFrame(bio_json_content, columns=bio_json_headers)
bio_df.columns

# %%
# # player_id=0 : not specifying PLAYER shooting
# # team_id=0 : not specifying TEAM of shooter
# # opp_team_id=0 : not specifying OPPOSING TEAM

# lineup = ['Stephen Curry', 'Klay Thompson', 'Kevin Durant']
# player_name = lineup[0]
# player_id = int(playerInfo[playerInfo.DISPLAY_FIRST_LAST == player_name].PERSON_ID)
# group_id = '%d'%player_id
# if len(lineup) > 1:
#     for player_name in lineup[1:]:
#         player_id = int(playerInfo[playerInfo.DISPLAY_FIRST_LAST == player_name].PERSON_ID)
#         group_id += ' - %d'%player_id
# print(group_id)

# team_id = 0
# opp_team_id = 0
# season = 2016

# # game_id='' : not specifying GAME ID
# # season_type : either 'Regular Season', 'Playoffs', 'Pre Season', or 'All Star'
# game_id = '0021700002'
# season_type = 'Regular Season'


# #########################################

# season_string = str(season) + '-' + str(season+1)[2:]

# PARAMS = {'LeagueID': '00', 
#           'Season': season_string,
#           'SeasonType': season_type,
#           'TeamID': str(team_id),
#           'Outcome': '',
#           'Location': '',
#           'Month': '0',
#           'SeasonSegment': '',
#           'DateFrom': '',
#           'DateTo': '',
#           'OpponentTeamID': str(opp_team_id),
#           'VsConference': '',
#           'VsDivision': '',
#           'GameSegment': '',
#           'Period': 0, 
#           'LastNGames': '0', 
#           'GameID': str(game_id),
#           'GROUP_ID': group_id,
#           'ContextMeasure': 'FGA',
#           'ContextFilter': '',
#           'PlayerPosition': ''
#          }

# # set headers, otherwise the API might not work
# HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'),
#            'referer': 'http://stats.nba.com/scores/'
#           }



# # Requesting data from stats.nba.com with the endpoint /stats/shotchartdetail
# # This gives us information on the matchup, game situtation, and xy-location
# # of every shot that we requested (falls under our filters)


# # NOTE: This API is not documented well and is poorly maintained. 
# # Let's hope they don't change the endpoints and/or required parameters
# r = requests.get('http://stats.nba.com/stats/shotchartlineupdetail', 
#                  params=PARAMS, headers=HEADERS)

# %%
# import re

# m = re.match('(^\\d+(?:(?: - \\d+){2,4})?$)', '201939 - 202691 - 201939 - 201939 - 201939')
# m.groups()
