# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import  offsetbox as osb
from matplotlib.cbook import get_sample_data
from matplotlib._png import read_png
from io import BytesIO, StringIO
from PIL import Image

import scipy
import numpy as np
import seaborn as sns
import pandas as pd

import plot_court
import lgcp_func as lgcp
import nmf_func as nmf
import sklearn.model_selection as sklearnMS
import pickle


import requests

import sys
import subprocess
import os
import simplejson as json
from pprint import pprint

from cache_func import cached
# Out:
# /Users/geoffreypoon/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
season_string = '2016-17'

shots_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/data/shots/shots_data_%s.json'%season_string
with open(shots_path, 'r') as json_data:
    d = json.load(json_data)
    json_data.close()
    
shots_dat = pd.DataFrame(d['resultSets'][0]['rowSet'], 
                         columns=d['resultSets'][0]['headers'])

# %%
shots_dat
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0021600001              2     201565
# 1       Shot Chart Detail  0021600001              3     201567
# 2       Shot Chart Detail  0021600001              5       2546
# 3       Shot Chart Detail  0021600001              7     204001
# 4       Shot Chart Detail  0021600001              8       2544
# 5       Shot Chart Detail  0021600001             10     202681
# 6       Shot Chart Detail  0021600001             12     201584
# 7       Shot Chart Detail  0021600001             14     201567
# 8       Shot Chart Detail  0021600001             18       2747
# 9       Shot Chart Detail  0021600001             19     204001
# 10      Shot Chart Detail  0021600001             27     201567
# 11      Shot Chart Detail  0021600001             29       2544
# 12      Shot Chart Detail  0021600001             31     201565
# 13      Shot Chart Detail  0021600001             33     201584
# 14      Shot Chart Detail  0021600001             35       2546
# 15      Shot Chart Detail  0021600001             37     202684
# 16      Shot Chart Detail  0021600001             39       2546
# 17      Shot Chart Detail  0021600001             40       2544
# 18      Shot Chart Detail  0021600001             42     201565
# 19      Shot Chart Detail  0021600001             44     202681
# 20      Shot Chart Detail  0021600001             46       2747
# 21      Shot Chart Detail  0021600001             48       2747
# 22      Shot Chart Detail  0021600001             56       2546
# 23      Shot Chart Detail  0021600001             58       2747
# 24      Shot Chart Detail  0021600001             60     201567
# 25      Shot Chart Detail  0021600001             65     201149
# 26      Shot Chart Detail  0021600001             67     202681
# 27      Shot Chart Detail  0021600001             69       2544
# 28      Shot Chart Detail  0021600001             70       2546
# 29      Shot Chart Detail  0021600001             71     202681
# ...                   ...         ...            ...        ...
# 209900  Shot Chart Detail  0021601230            424     202348
# 209901  Shot Chart Detail  0021601230            426    1627817
# 209902  Shot Chart Detail  0021601230            427     202348
# 209903  Shot Chart Detail  0021601230            436     203090
# 209904  Shot Chart Detail  0021601230            437    1626253
# 209905  Shot Chart Detail  0021601230            438    1626192
# 209906  Shot Chart Detail  0021601230            440    1626253
# 209907  Shot Chart Detail  0021601230            441    1627817
# 209908  Shot Chart Detail  0021601230            453     202348
# 209909  Shot Chart Detail  0021601230            454    1627767
# 209910  Shot Chart Detail  0021601230            456     203086
# 209911  Shot Chart Detail  0021601230            458     201582
# 209912  Shot Chart Detail  0021601230            466    1627767
# 209913  Shot Chart Detail  0021601230            472    1626192
# 209914  Shot Chart Detail  0021601230            474    1626188
# 209915  Shot Chart Detail  0021601230            476    1627817
# 209916  Shot Chart Detail  0021601230            479    1626192
# 209917  Shot Chart Detail  0021601230            481    1627817
# 209918  Shot Chart Detail  0021601230            484    1627767
# 209919  Shot Chart Detail  0021601230            485     203086
# 209920  Shot Chart Detail  0021601230            487     202348
# 209921  Shot Chart Detail  0021601230            489     202348
# 209922  Shot Chart Detail  0021601230            490     203086
# 209923  Shot Chart Detail  0021601230            500     203943
# 209924  Shot Chart Detail  0021601230            505    1627767
# 209925  Shot Chart Detail  0021601230            507     203086
# 209926  Shot Chart Detail  0021601230            511     203943
# 209927  Shot Chart Detail  0021601230            512    1626188
# 209928  Shot Chart Detail  0021601230            514     203086
# 209929  Shot Chart Detail  0021601230            516     202348
#
#                PLAYER_NAME     TEAM_ID               TEAM_NAME  PERIOD  \
# 0             Derrick Rose  1610612752         New York Knicks       1
# 1               Kevin Love  1610612739     Cleveland Cavaliers       1
# 2          Carmelo Anthony  1610612752         New York Knicks       1
# 3       Kristaps Porzingis  1610612752         New York Knicks       1
# 4             LeBron James  1610612739     Cleveland Cavaliers       1
# 5             Kyrie Irving  1610612739     Cleveland Cavaliers       1
# 6             Courtney Lee  1610612752         New York Knicks       1
# 7               Kevin Love  1610612739     Cleveland Cavaliers       1
# 8                 JR Smith  1610612739     Cleveland Cavaliers       1
# 9       Kristaps Porzingis  1610612752         New York Knicks       1
# 10              Kevin Love  1610612739     Cleveland Cavaliers       1
# 11            LeBron James  1610612739     Cleveland Cavaliers       1
# 12            Derrick Rose  1610612752         New York Knicks       1
# 13            Courtney Lee  1610612752         New York Knicks       1
# 14         Carmelo Anthony  1610612752         New York Knicks       1
# 15        Tristan Thompson  1610612739     Cleveland Cavaliers       1
# 16         Carmelo Anthony  1610612752         New York Knicks       1
# 17            LeBron James  1610612739     Cleveland Cavaliers       1
# 18            Derrick Rose  1610612752         New York Knicks       1
# 19            Kyrie Irving  1610612739     Cleveland Cavaliers       1
# 20                JR Smith  1610612739     Cleveland Cavaliers       1
# 21                JR Smith  1610612739     Cleveland Cavaliers       1
# 22         Carmelo Anthony  1610612752         New York Knicks       1
# 23                JR Smith  1610612739     Cleveland Cavaliers       1
# 24              Kevin Love  1610612739     Cleveland Cavaliers       1
# 25             Joakim Noah  1610612752         New York Knicks       1
# 26            Kyrie Irving  1610612739     Cleveland Cavaliers       1
# 27            LeBron James  1610612739     Cleveland Cavaliers       1
# 28         Carmelo Anthony  1610612752         New York Knicks       1
# 29            Kyrie Irving  1610612739     Cleveland Cavaliers       1
# ...                    ...         ...                     ...     ...
# 209900     Jordan Crawford  1610612740    New Orleans Pelicans       4
# 209901      Tim Quarterman  1610612757  Portland Trail Blazers       4
# 209902     Jordan Crawford  1610612740    New Orleans Pelicans       4
# 209903    Maurice Harkless  1610612757  Portland Trail Blazers       4
# 209904        Axel Toupane  1610612740    New Orleans Pelicans       4
# 209905     Pat Connaughton  1610612757  Portland Trail Blazers       4
# 209906        Axel Toupane  1610612740    New Orleans Pelicans       4
# 209907      Tim Quarterman  1610612757  Portland Trail Blazers       4
# 209908     Jordan Crawford  1610612740    New Orleans Pelicans       4
# 209909       Cheick Diallo  1610612740    New Orleans Pelicans       4
# 209910      Meyers Leonard  1610612757  Portland Trail Blazers       4
# 209911       Alexis Ajinca  1610612740    New Orleans Pelicans       4
# 209912       Cheick Diallo  1610612740    New Orleans Pelicans       4
# 209913     Pat Connaughton  1610612757  Portland Trail Blazers       4
# 209914          Quinn Cook  1610612740    New Orleans Pelicans       4
# 209915      Tim Quarterman  1610612757  Portland Trail Blazers       4
# 209916     Pat Connaughton  1610612757  Portland Trail Blazers       4
# 209917      Tim Quarterman  1610612757  Portland Trail Blazers       4
# 209918       Cheick Diallo  1610612740    New Orleans Pelicans       4
# 209919      Meyers Leonard  1610612757  Portland Trail Blazers       4
# 209920     Jordan Crawford  1610612740    New Orleans Pelicans       4
# 209921     Jordan Crawford  1610612740    New Orleans Pelicans       4
# 209922      Meyers Leonard  1610612757  Portland Trail Blazers       4
# 209923         Noah Vonleh  1610612757  Portland Trail Blazers       4
# 209924       Cheick Diallo  1610612740    New Orleans Pelicans       4
# 209925      Meyers Leonard  1610612757  Portland Trail Blazers       4
# 209926         Noah Vonleh  1610612757  Portland Trail Blazers       4
# 209927          Quinn Cook  1610612740    New Orleans Pelicans       4
# 209928      Meyers Leonard  1610612757  Portland Trail Blazers       4
# 209929     Jordan Crawford  1610612740    New Orleans Pelicans       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING ...          SHOT_ZONE_AREA  \
# 0                      11                 40 ...               Center(C)
# 1                      11                 26 ...               Center(C)
# 2                      11                 16 ...   Right Side Center(RC)
# 3                      11                 15 ...               Center(C)
# 4                      10                 59 ...            Left Side(L)
# 5                      10                 46 ...   Right Side Center(RC)
# 6                      10                 34 ...    Left Side Center(LC)
# 7                      10                 21 ...    Left Side Center(LC)
# 8                       9                 59 ...               Center(C)
# 9                       9                 47 ...            Left Side(L)
# 10                      9                 33 ...   Right Side Center(RC)
# 11                      9                 27 ...    Left Side Center(LC)
# 12                      9                 18 ...           Right Side(R)
# 13                      9                  8 ...   Right Side Center(RC)
# 14                      9                  7 ...               Center(C)
# 15                      8                 58 ...               Center(C)
# 16                      8                 47 ...           Right Side(R)
# 17                      8                 16 ...   Right Side Center(RC)
# 18                      8                  9 ...               Center(C)
# 19                      8                  1 ...               Center(C)
# 20                      7                 56 ...   Right Side Center(RC)
# 21                      7                 33 ...   Right Side Center(RC)
# 22                      7                 12 ...            Left Side(L)
# 23                      6                 52 ...    Left Side Center(LC)
# 24                      6                 48 ...               Center(C)
# 25                      6                 24 ...               Center(C)
# 26                      6                 13 ...               Center(C)
# 27                      5                 56 ...               Center(C)
# 28                      5                 38 ...           Right Side(R)
# 29                      5                 25 ...               Center(C)
# ...                   ...                ... ...                     ...
# 209900                  9                 26 ...   Right Side Center(RC)
# 209901                  9                 21 ...    Left Side Center(LC)
# 209902                  9                  2 ...            Left Side(L)
# 209903                  8                 41 ...               Center(C)
# 209904                  8                 20 ...               Center(C)
# 209905                  8                  3 ...   Right Side Center(RC)
# 209906                  7                 45 ...    Left Side Center(LC)
# 209907                  7                 26 ...    Left Side Center(LC)
# 209908                  6                 47 ...               Center(C)
# 209909                  6                 43 ...               Center(C)
# 209910                  6                 19 ...           Right Side(R)
# 209911                  6                  9 ...               Center(C)
# 209912                  5                 24 ...               Center(C)
# 209913                  5                  8 ...   Right Side Center(RC)
# 209914                  4                 51 ...    Left Side Center(LC)
# 209915                  4                 38 ...               Center(C)
# 209916                  4                 14 ...               Center(C)
# 209917                  4                 13 ...   Right Side Center(RC)
# 209918                  4                  1 ...               Center(C)
# 209919                  3                 41 ...               Center(C)
# 209920                  3                 30 ...            Left Side(L)
# 209921                  3                  4 ...               Center(C)
# 209922                  2                 38 ...            Left Side(L)
# 209923                  2                  2 ...               Center(C)
# 209924                  1                 49 ...               Center(C)
# 209925                  1                 30 ...            Left Side(L)
# 209926                  1                 23 ...               Center(C)
# 209927                  1                 11 ...    Left Side Center(LC)
# 209928                  0                 47 ...            Left Side(L)
# 209929                  0                 28 ...    Left Side Center(LC)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0       Less Than 8 ft.             0     4     8                   1
# 1       Less Than 8 ft.             3   -11    36                   1
# 2             16-24 ft.            19   148   129                   1
# 3       Less Than 8 ft.             2    24    -1                   1
# 4              8-16 ft.            11   -79    80                   1
# 5               24+ ft.            24   107   223                   1
# 6             16-24 ft.            17  -109   141                   1
# 7               24+ ft.            25  -191   164                   1
# 8       Less Than 8 ft.             0    -1     2                   1
# 9             16-24 ft.            16  -150    61                   1
# 10            16-24 ft.            19   130   149                   1
# 11              24+ ft.            24  -166   185                   1
# 12             8-16 ft.            12   122     2                   1
# 13              24+ ft.            25   140   210                   1
# 14      Less Than 8 ft.             0     2     7                   1
# 15             8-16 ft.             8    38    80                   1
# 16             8-16 ft.            15   159     2                   1
# 17              24+ ft.            25   133   213                   1
# 18      Less Than 8 ft.             0    -2     7                   1
# 19      Less Than 8 ft.             0     0     3                   1
# 20              24+ ft.            25   177   178                   1
# 21              24+ ft.            24    89   228                   1
# 22              24+ ft.            23  -232     3                   1
# 23              24+ ft.            25  -163   198                   1
# 24      Less Than 8 ft.             1    14    -6                   1
# 25      Less Than 8 ft.             0    -1     3                   1
# 26             8-16 ft.            15   -32   149                   1
# 27      Less Than 8 ft.             0     9    -1                   1
# 28            16-24 ft.            22   186   132                   1
# 29      Less Than 8 ft.             1    12    13                   1
# ...                 ...           ...   ...   ...                 ...
# 209900          24+ ft.            24    92   223                   1
# 209901          24+ ft.            27  -169   213                   1
# 209902         8-16 ft.             8   -84    28                   1
# 209903  Less Than 8 ft.             2   -20    11                   1
# 209904  Less Than 8 ft.             2   -12    18                   1
# 209905          24+ ft.            24   200   144                   1
# 209906        16-24 ft.            20  -133   154                   1
# 209907        16-24 ft.            21  -135   164                   1
# 209908  Less Than 8 ft.             5   -32    46                   1
# 209909  Less Than 8 ft.             1     2    13                   1
# 209910         8-16 ft.            12   123    31                   1
# 209911  Less Than 8 ft.             6   -19    67                   1
# 209912  Less Than 8 ft.             1    -6    16                   1
# 209913          24+ ft.            25   130   223                   1
# 209914        16-24 ft.            21   -94   193                   1
# 209915          24+ ft.            26   -47   257                   1
# 209916  Less Than 8 ft.             1    17     8                   1
# 209917          24+ ft.            25   192   169                   1
# 209918  Less Than 8 ft.             1   -16    11                   1
# 209919  Less Than 8 ft.             5    22    51                   1
# 209920         8-16 ft.            12  -106    57                   1
# 209921          24+ ft.            26   -43   259                   1
# 209922        16-24 ft.            20  -189    70                   1
# 209923  Less Than 8 ft.             1    15     2                   1
# 209924         8-16 ft.            14   -38   136                   1
# 209925         8-16 ft.            10   -99    18                   1
# 209926  Less Than 8 ft.             4     2    46                   1
# 209927        16-24 ft.            18   -61   175                   1
# 209928         8-16 ft.             8   -63    61                   1
# 209929        16-24 ft.            18   -68   174                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    1   20161025  CLE  NYK
# 1                    0   20161025  CLE  NYK
# 2                    0   20161025  CLE  NYK
# 3                    1   20161025  CLE  NYK
# 4                    1   20161025  CLE  NYK
# 5                    0   20161025  CLE  NYK
# 6                    0   20161025  CLE  NYK
# 7                    0   20161025  CLE  NYK
# 8                    1   20161025  CLE  NYK
# 9                    0   20161025  CLE  NYK
# 10                   0   20161025  CLE  NYK
# 11                   0   20161025  CLE  NYK
# 12                   0   20161025  CLE  NYK
# 13                   0   20161025  CLE  NYK
# 14                   0   20161025  CLE  NYK
# 15                   0   20161025  CLE  NYK
# 16                   1   20161025  CLE  NYK
# 17                   0   20161025  CLE  NYK
# 18                   0   20161025  CLE  NYK
# 19                   0   20161025  CLE  NYK
# 20                   1   20161025  CLE  NYK
# 21                   0   20161025  CLE  NYK
# 22                   1   20161025  CLE  NYK
# 23                   0   20161025  CLE  NYK
# 24                   1   20161025  CLE  NYK
# 25                   0   20161025  CLE  NYK
# 26                   1   20161025  CLE  NYK
# 27                   1   20161025  CLE  NYK
# 28                   1   20161025  CLE  NYK
# 29                   0   20161025  CLE  NYK
# ...                ...        ...  ...  ...
# 209900               0   20170412  POR  NOP
# 209901               1   20170412  POR  NOP
# 209902               0   20170412  POR  NOP
# 209903               1   20170412  POR  NOP
# 209904               1   20170412  POR  NOP
# 209905               1   20170412  POR  NOP
# 209906               1   20170412  POR  NOP
# 209907               0   20170412  POR  NOP
# 209908               0   20170412  POR  NOP
# 209909               1   20170412  POR  NOP
# 209910               0   20170412  POR  NOP
# 209911               1   20170412  POR  NOP
# 209912               1   20170412  POR  NOP
# 209913               0   20170412  POR  NOP
# 209914               0   20170412  POR  NOP
# 209915               0   20170412  POR  NOP
# 209916               0   20170412  POR  NOP
# 209917               0   20170412  POR  NOP
# 209918               1   20170412  POR  NOP
# 209919               0   20170412  POR  NOP
# 209920               1   20170412  POR  NOP
# 209921               1   20170412  POR  NOP
# 209922               1   20170412  POR  NOP
# 209923               1   20170412  POR  NOP
# 209924               0   20170412  POR  NOP
# 209925               0   20170412  POR  NOP
# 209926               1   20170412  POR  NOP
# 209927               0   20170412  POR  NOP
# 209928               0   20170412  POR  NOP
# 209929               0   20170412  POR  NOP
#
# [209930 rows x 24 columns]
