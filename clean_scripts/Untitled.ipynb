# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import  offsetbox as osb
from matplotlib.cbook import get_sample_data
from matplotlib._png import read_png
from io import BytesIO, StringIO
from PIL import Image

import scipy
import numpy as np
import seaborn as sns
import pandas as pd

import plot_court
import lgcp_func as lgcp
import nmf_func as nmf
import sklearn.model_selection as sklearnMS


import requests

import sys
import subprocess
import os
import simplejson as json
from pprint import pprint

from cache_func import cached
# Out:
# /Users/geoffreypoon/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def train_test_split_player_shotInfo(randSeed = 546682):
    shots_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + '/data/shots/shots.csv'
    shots_dat = pd.read_csv(shots_path)
    
#    headers_2015 = ['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 
#                       'PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_NAME', 
#                       'PERIOD', 'MINUTES_REMAINING', 'SECONDS_REMAINING', 
#                       'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#                       'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 
#                       'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#                       'LOC_X', 'LOC_Y', 
#                       'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 
#                       'GAME_DATE', 'HTM', 'VTM']       # HTM = Home team, VTM = Visiting team
    
    df = pd.DataFrame(shots_dat, 
                      columns = ['PLAYER_ID', 'PLAYER_NAME', 
                                 'TEAM_ID', 'TEAM_NAME', 'ACTION_TYPE',
                                 'SHOT_DISTANCE', 'SHOT_TYPE', 
                                 'LOC_X', 'LOC_Y', 
                                 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG'])
    
    num_players = 300
    top_players_shotNum = df.PLAYER_NAME.value_counts()[:num_players]
    top_players_nameList = top_players_shotNum.index.tolist()

    train_players_df = {}
    test_players_df = {}
    playersID = {}
    for i, player in enumerate(set(top_players_nameList)):  
        player_df = df[df.PLAYER_NAME == player]
        train_players_df[player], test_players_df[player] = \
                sklearnMS.train_test_split(player_df, test_size=0.2, random_state=randSeed)
        playersID[player] = player_df.PLAYER_ID.unique()[0]
        
    return train_players_df, test_players_df, top_players_nameList, playersID

#######################

def gen_players_shotHist(players_df, top_players_nameList, flag='SHOT_ATTEMPTED_FLAG'):
    bins, binRange = ([25,18], [[-250,250], [-47.5,312.5]])
    
    player_shotHist = {}
    for i, player in enumerate(top_players_nameList):  
        temp = players_df[player]
        hist2d, xedges, yedges, binnumber = scipy.stats.binned_statistic_2d(temp.LOC_X, temp.LOC_Y, 
                                                                            temp[flag],
                                                                            statistic='sum',
                                                                            bins=bins, 
                                                                            range=binRange)
        player_shotHist[player] = hist2d.flatten() 
    return player_shotHist, (bins, binRange, xedges, yedges, binnumber)

# %%
# =============================================================================
# FUNCTIONS: Plot histograms
# =============================================================================    
        
    
def acquire_playerPic(PlayerID):
    url = "http://stats.nba.com/media/players/230x185/"+str(PlayerID)+".png"
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img
        


def plot_shotHist(player_shotHist, player, binDat, fileName, 
                  title='', norm_Opt='linear', plot_size=(5,5)):   
    bins, binRange, xedges, yedges, binnumber = binDat
    Xn_v = player_shotHist
    temp = np.array(Xn_v, dtype='float')/np.sum(Xn_v)
    shotHist_v = np.reshape(temp, bins)
    ##########
    extent = np.min(xedges), np.max(xedges), np.max(yedges), np.min(yedges)
    
    fig = plt.figure(figsize=plot_size)
    ax = plt.axes()
    
    plot_court.draw_court(outer_lines=True, lw=1.5)
    
    
    cmap = plt.cm.magma_r
    if norm_Opt == 'log':
        plt.imshow(shotHist_v.T, cmap=cmap, 
                   norm=colors.LogNorm(vmin=1e-4, vmax=1e-1),
                   alpha=.85, extent=extent)
    else:
        plt.imshow(np.ma.masked_where(shotHist_v.T == 0., shotHist_v.T), 
                   cmap=cmap, alpha=.85, extent=extent)
    
    ax.set_xlim([-300,300])
    ax.set_ylim([-100,500])
    ax.grid('off')
    ax.axis('off')
    ax.set_title('%s: %s'%(player, title), fontsize=15)
#    plt.axis('off')
    fig.tight_layout()
    fig.savefig(fileName, dpi=700)

# %%
def gen_shotHist_plots(player, phi=30, seed=546682):
    dirName = 'SHOT_ATTEMPTED_FLAG/shotHist_LGCP_phi%d_seed%d/'%(phi,seed)
    fileName = 'norm_lambda_%s.txt'%player
    
    outfileName = 'lgcp_shotHist_%s.png'%player
    plot_shotHist(np.loadtxt(dirName + fileName), player, binDat, 
                  outfileName, title='LGCP', norm_Opt='log')
    
    outfileName = 'raw_shotHist_%s.png'%player
    plot_shotHist(players_shotHist_train[player], player, binDat, 
                  outfileName, title='raw', norm_Opt='log')

# %%
randSeed = 546682

train_players_df, test_players_df, top_players_nameList, playersID = \
        train_test_split_player_shotInfo(randSeed = randSeed)
playersName = dict((v,k) for k,v in playersID.items())
# playersID-- key: name, value: ID
# playersName-- key: ID, value: name


flag_name = 'SHOT_ATTEMPTED_FLAG'



players_shotAttm_train, binDat = gen_players_shotHist(train_players_df, 
                                                      top_players_nameList,
                                                      flag=flag_name)
players_shotAttm_test, binDat = gen_players_shotHist(test_players_df, 
                                                     top_players_nameList,
                                                     flag=flag_name)
bins, binRange, xedges, yedges, binnumber = binDat

# %%
flag_name = 'SHOT_MADE_FLAG'



players_shotMade_train, binDat = gen_players_shotHist(train_players_df, 
                                                      top_players_nameList,
                                                      flag=flag_name)
players_shotMade_test, binDat = gen_players_shotHist(train_players_df, 
                                                     top_players_nameList,
                                                     flag=flag_name)
bins, binRange, xedges, yedges, binnumber = binDat

# %%
[[players_shotAttm_train[i].sum(), players_shotMade_train[i].sum(), 
  players_shotMade_train[i].sum()/players_shotAttm_train[i].sum()]
 for i in top_players_nameList]
# Out:
# [[1291.0, 567.0, 0.43919442292796285],
#  [1259.0, 643.0, 0.5107227958697379],
#  [1173.0, 495.0, 0.42199488491048592],
#  [1153.0, 473.0, 0.41023417172593235],
#  [1150.0, 524.0, 0.45565217391304347],
#  [1143.0, 503.0, 0.44006999125109364],
#  [1130.0, 594.0, 0.52566371681415924],
#  [1104.0, 507.0, 0.45923913043478259],
#  [1105.0, 482.0, 0.43619909502262444],
#  [1103.0, 555.0, 0.50317316409791479],
#  [1096.0, 489.0, 0.44616788321167883],
#  [1074.0, 464.0, 0.43202979515828677],
#  [1062.0, 479.0, 0.45103578154425611],
#  [1061.0, 452.0, 0.42601319509896324],
#  [1045.0, 458.0, 0.43827751196172249],
#  [1034.0, 470.0, 0.45454545454545453],
#  [989.0, 417.0, 0.42163801820020225],
#  [960.0, 410.0, 0.42708333333333331],
#  [950.0, 410.0, 0.43157894736842106],
#  [942.0, 433.0, 0.45966029723991508],
#  [924.0, 479.0, 0.51839826839826841],
#  [921.0, 501.0, 0.5439739413680782],
#  [912.0, 403.0, 0.44188596491228072],
#  [906.0, 446.0, 0.49227373068432673],
#  [888.0, 322.0, 0.36261261261261263],
#  [886.0, 410.0, 0.46275395033860045],
#  [888.0, 394.0, 0.44369369369369371],
#  [873.0, 373.0, 0.42726231386025199],
#  [869.0, 439.0, 0.50517836593785959],
#  [849.0, 401.0, 0.47232037691401652],
#  [843.0, 440.0, 0.52194543297746143],
#  [837.0, 358.0, 0.42771804062126645],
#  [838.0, 420.0, 0.50119331742243434],
#  [835.0, 423.0, 0.50658682634730534],
#  [836.0, 424.0, 0.50717703349282295],
#  [820.0, 392.0, 0.47804878048780486],
#  [813.0, 361.0, 0.44403444034440342],
#  [807.0, 336.0, 0.41635687732342008],
#  [804.0, 404.0, 0.50248756218905477],
#  [805.0, 379.0, 0.47080745341614905],
#  [796.0, 368.0, 0.46231155778894473],
#  [788.0, 346.0, 0.43908629441624364],
#  [781.0, 343.0, 0.43918053777208704],
#  [779.0, 318.0, 0.40821566110397944],
#  [774.0, 336.0, 0.43410852713178294],
#  [771.0, 339.0, 0.43968871595330739],
#  [770.0, 319.0, 0.41428571428571431],
#  [768.0, 395.0, 0.51432291666666663],
#  [760.0, 312.0, 0.41052631578947368],
#  [765.0, 349.0, 0.45620915032679737],
#  [756.0, 303.0, 0.40079365079365081],
#  [753.0, 328.0, 0.43559096945551129],
#  [752.0, 396.0, 0.52659574468085102],
#  [740.0, 298.0, 0.4027027027027027],
#  [743.0, 335.0, 0.45087483176312249],
#  [739.0, 313.0, 0.42354533152909335],
#  [736.0, 339.0, 0.46059782608695654],
#  [723.0, 356.0, 0.49239280774550487],
#  [721.0, 262.0, 0.36338418862690708],
#  [719.0, 350.0, 0.48678720445062584],
#  [713.0, 296.0, 0.41514726507713884],
#  [711.0, 331.0, 0.46554149085794655],
#  [708.0, 297.0, 0.41949152542372881],
#  [703.0, 313.0, 0.44523470839260315],
#  [697.0, 335.0, 0.48063127690100432],
#  [697.0, 306.0, 0.43902439024390244],
#  [697.0, 334.0, 0.47919655667144906],
#  [694.0, 337.0, 0.48559077809798273],
#  [690.0, 293.0, 0.4246376811594203],
#  [682.0, 313.0, 0.45894428152492667],
#  [686.0, 282.0, 0.41107871720116618],
#  [682.0, 265.0, 0.38856304985337242],
#  [676.0, 286.0, 0.42307692307692307],
#  [668.0, 295.0, 0.44161676646706588],
#  [653.0, 288.0, 0.44104134762633995],
#  [654.0, 326.0, 0.49847094801223241],
#  [649.0, 286.0, 0.44067796610169491],
#  [646.0, 327.0, 0.50619195046439625],
#  [642.0, 270.0, 0.42056074766355139],
#  [634.0, 287.0, 0.45268138801261831],
#  [636.0, 269.0, 0.42295597484276731],
#  [623.0, 275.0, 0.44141252006420545],
#  [624.0, 320.0, 0.51282051282051277],
#  [621.0, 265.0, 0.42673107890499196],
#  [617.0, 251.0, 0.40680713128038898],
#  [618.0, 298.0, 0.48220064724919093],
#  [618.0, 254.0, 0.4110032362459547],
#  [613.0, 292.0, 0.47634584013050568],
#  [611.0, 291.0, 0.47626841243862522],
#  [611.0, 353.0, 0.57774140752864156],
#  [602.0, 269.0, 0.44684385382059799],
#  [598.0, 258.0, 0.43143812709030099],
#  [595.0, 267.0, 0.44873949579831934],
#  [594.0, 266.0, 0.44781144781144783],
#  [588.0, 260.0, 0.44217687074829931],
#  [581.0, 244.0, 0.41996557659208261],
#  [581.0, 247.0, 0.42512908777969016],
#  [578.0, 252.0, 0.43598615916955019],
#  [575.0, 202.0, 0.35130434782608694],
#  [574.0, 328.0, 0.5714285714285714],
#  [572.0, 236.0, 0.41258741258741261],
#  [572.0, 244.0, 0.42657342657342656],
#  [567.0, 271.0, 0.47795414462081126],
#  [566.0, 222.0, 0.392226148409894],
#  [565.0, 263.0, 0.46548672566371679],
#  [568.0, 283.0, 0.49823943661971831],
#  [565.0, 264.0, 0.46725663716814159],
#  [564.0, 222.0, 0.39361702127659576],
#  [556.0, 220.0, 0.39568345323741005],
#  [553.0, 234.0, 0.42314647377938519],
#  [549.0, 211.0, 0.38433515482695813],
#  [550.0, 226.0, 0.41090909090909089],
#  [545.0, 332.0, 0.60917431192660554],
#  [541.0, 219.0, 0.40480591497227358],
#  [542.0, 259.0, 0.477859778597786],
#  [542.0, 225.0, 0.4151291512915129],
#  [541.0, 250.0, 0.46210720887245843],
#  [529.0, 289.0, 0.54631379962192816],
#  [528.0, 229.0, 0.43371212121212122],
#  [517.0, 257.0, 0.49709864603481624],
#  [514.0, 224.0, 0.43579766536964981],
#  [510.0, 231.0, 0.45294117647058824],
#  [500.0, 192.0, 0.38400000000000001],
#  [505.0, 203.0, 0.401980198019802],
#  [501.0, 213.0, 0.42514970059880242],
#  [506.0, 238.0, 0.47035573122529645],
#  [500.0, 282.0, 0.56399999999999995],
#  [499.0, 203.0, 0.40681362725450904],
#  [493.0, 222.0, 0.45030425963488846],
#  [494.0, 228.0, 0.46153846153846156],
#  [492.0, 212.0, 0.43089430894308944],
#  [485.0, 207.0, 0.42680412371134019],
#  [485.0, 195.0, 0.40206185567010311],
#  [482.0, 241.0, 0.5],
#  [478.0, 302.0, 0.63179916317991636],
#  [480.0, 254.0, 0.52916666666666667],
#  [478.0, 204.0, 0.42677824267782427],
#  [475.0, 175.0, 0.36842105263157893],
#  [476.0, 216.0, 0.45378151260504201],
#  [474.0, 219.0, 0.46202531645569622],
#  [472.0, 217.0, 0.4597457627118644],
#  [466.0, 186.0, 0.39914163090128757],
#  [468.0, 232.0, 0.49572649572649574],
#  [464.0, 181.0, 0.39008620689655171],
#  [467.0, 174.0, 0.37259100642398285],
#  [462.0, 205.0, 0.44372294372294374],
#  [464.0, 191.0, 0.41163793103448276],
#  [463.0, 245.0, 0.52915766738660908],
#  [456.0, 218.0, 0.47807017543859648],
#  [449.0, 199.0, 0.44320712694877507],
#  [447.0, 171.0, 0.3825503355704698],
#  [443.0, 168.0, 0.37923250564334088],
#  [444.0, 206.0, 0.46396396396396394],
#  [442.0, 199.0, 0.45022624434389141],
#  [440.0, 191.0, 0.43409090909090908],
#  [432.0, 169.0, 0.39120370370370372],
#  [439.0, 234.0, 0.53302961275626426],
#  [436.0, 174.0, 0.39908256880733944],
#  [429.0, 168.0, 0.39160839160839161],
#  [428.0, 245.0, 0.57242990654205606],
#  [424.0, 205.0, 0.48349056603773582],
#  [421.0, 180.0, 0.42755344418052255],
#  [417.0, 140.0, 0.33573141486810554],
#  [418.0, 173.0, 0.4138755980861244],
#  [411.0, 205.0, 0.49878345498783455],
#  [410.0, 176.0, 0.42926829268292682],
#  [408.0, 165.0, 0.40441176470588236],
#  [407.0, 183.0, 0.44963144963144963],
#  [406.0, 277.0, 0.68226600985221675],
#  [405.0, 166.0, 0.40987654320987654],
#  [404.0, 188.0, 0.46534653465346537],
#  [403.0, 164.0, 0.40694789081885857],
#  [402.0, 193.0, 0.48009950248756217],
#  [401.0, 177.0, 0.44139650872817954],
#  [400.0, 216.0, 0.54000000000000004],
#  [395.0, 193.0, 0.48860759493670886],
#  [392.0, 162.0, 0.41326530612244899],
#  [391.0, 175.0, 0.4475703324808184],
#  [389.0, 184.0, 0.47300771208226222],
#  [389.0, 187.0, 0.48071979434447298],
#  [387.0, 161.0, 0.41602067183462532],
#  [384.0, 138.0, 0.359375],
#  [378.0, 185.0, 0.48941798941798942],
#  [374.0, 176.0, 0.47058823529411764],
#  [375.0, 172.0, 0.45866666666666667],
#  [367.0, 151.0, 0.41144414168937332],
#  [371.0, 180.0, 0.48517520215633425],
#  [366.0, 182.0, 0.49726775956284153],
#  [367.0, 155.0, 0.42234332425068122],
#  [363.0, 159.0, 0.43801652892561982],
#  [364.0, 170.0, 0.46703296703296704],
#  [363.0, 160.0, 0.44077134986225897],
#  [358.0, 214.0, 0.5977653631284916],
#  [358.0, 196.0, 0.54748603351955305],
#  [355.0, 185.0, 0.52112676056338025],
#  [352.0, 141.0, 0.40056818181818182],
#  [351.0, 142.0, 0.40455840455840458],
#  [352.0, 169.0, 0.48011363636363635],
#  [350.0, 173.0, 0.49428571428571427],
#  [349.0, 189.0, 0.54154727793696278],
#  [346.0, 148.0, 0.4277456647398844],
#  [347.0, 152.0, 0.43804034582132567],
#  [347.0, 160.0, 0.4610951008645533],
#  [345.0, 155.0, 0.44927536231884058],
#  [344.0, 151.0, 0.43895348837209303],
#  [339.0, 193.0, 0.56932153392330387],
#  [340.0, 209.0, 0.61470588235294121],
#  [332.0, 139.0, 0.41867469879518071],
#  [336.0, 202.0, 0.60119047619047616],
#  [332.0, 143.0, 0.43072289156626509],
#  [328.0, 148.0, 0.45121951219512196],
#  [333.0, 123.0, 0.36936936936936937],
#  [332.0, 148.0, 0.44578313253012047],
#  [327.0, 149.0, 0.45565749235474007],
#  [328.0, 145.0, 0.44207317073170732],
#  [326.0, 156.0, 0.4785276073619632],
#  [326.0, 118.0, 0.3619631901840491],
#  [316.0, 188.0, 0.59493670886075944],
#  [315.0, 103.0, 0.32698412698412699],
#  [311.0, 126.0, 0.40514469453376206],
#  [311.0, 149.0, 0.47909967845659163],
#  [309.0, 150.0, 0.4854368932038835],
#  [306.0, 161.0, 0.52614379084967322],
#  [307.0, 166.0, 0.54071661237785018],
#  [305.0, 159.0, 0.52131147540983602],
#  [302.0, 134.0, 0.44370860927152317],
#  [304.0, 160.0, 0.52631578947368418],
#  [302.0, 162.0, 0.53642384105960261],
#  [299.0, 141.0, 0.47157190635451507],
#  [297.0, 121.0, 0.40740740740740738],
#  [290.0, 134.0, 0.46206896551724136],
#  [292.0, 156.0, 0.53424657534246578],
#  [295.0, 135.0, 0.4576271186440678],
#  [296.0, 148.0, 0.5],
#  [295.0, 106.0, 0.35932203389830508],
#  [289.0, 136.0, 0.47058823529411764],
#  [290.0, 134.0, 0.46206896551724136],
#  [287.0, 164.0, 0.5714285714285714],
#  [284.0, 117.0, 0.4119718309859155],
#  [283.0, 155.0, 0.54770318021201414],
#  [279.0, 110.0, 0.3942652329749104],
#  [275.0, 118.0, 0.42909090909090908],
#  [278.0, 125.0, 0.44964028776978415],
#  [277.0, 98.0, 0.35379061371841153],
#  [277.0, 118.0, 0.4259927797833935],
#  [270.0, 108.0, 0.40000000000000002],
#  [271.0, 152.0, 0.56088560885608851],
#  [270.0, 99.0, 0.36666666666666664],
#  [269.0, 172.0, 0.63940520446096649],
#  [268.0, 142.0, 0.52985074626865669],
#  [265.0, 105.0, 0.39622641509433965],
#  [266.0, 108.0, 0.40601503759398494],
#  [264.0, 109.0, 0.4128787878787879],
#  [260.0, 101.0, 0.38846153846153847],
#  [257.0, 103.0, 0.40077821011673154],
#  [253.0, 141.0, 0.55731225296442688],
#  [252.0, 114.0, 0.45238095238095238],
#  [250.0, 97.0, 0.38800000000000001],
#  [252.0, 125.0, 0.49603174603174605],
#  [251.0, 147.0, 0.58565737051792832],
#  [249.0, 110.0, 0.44176706827309237],
#  [247.0, 113.0, 0.45748987854251011],
#  [248.0, 120.0, 0.4838709677419355],
#  [245.0, 88.0, 0.35918367346938773],
#  [243.0, 106.0, 0.43621399176954734],
#  [238.0, 86.0, 0.36134453781512604],
#  [239.0, 89.0, 0.3723849372384937],
#  [240.0, 106.0, 0.44166666666666665],
#  [239.0, 88.0, 0.3682008368200837],
#  [238.0, 118.0, 0.49579831932773111],
#  [236.0, 119.0, 0.50423728813559321],
#  [236.0, 110.0, 0.46610169491525422],
#  [235.0, 95.0, 0.40425531914893614],
#  [232.0, 133.0, 0.57327586206896552],
#  [232.0, 96.0, 0.41379310344827586],
#  [231.0, 106.0, 0.45887445887445888],
#  [232.0, 116.0, 0.5],
#  [231.0, 98.0, 0.42424242424242425],
#  [229.0, 128.0, 0.55895196506550215],
#  [227.0, 90.0, 0.3964757709251101],
#  [223.0, 141.0, 0.63228699551569512],
#  [222.0, 92.0, 0.4144144144144144],
#  [219.0, 89.0, 0.40639269406392692],
#  [221.0, 92.0, 0.41628959276018102],
#  [217.0, 110.0, 0.50691244239631339],
#  [216.0, 100.0, 0.46296296296296297],
#  [216.0, 102.0, 0.47222222222222221],
#  [215.0, 84.0, 0.39069767441860465],
#  [216.0, 95.0, 0.43981481481481483],
#  [210.0, 91.0, 0.43333333333333335],
#  [212.0, 70.0, 0.330188679245283],
#  [207.0, 84.0, 0.40579710144927539],
#  [203.0, 104.0, 0.51231527093596063],
#  [200.0, 121.0, 0.60499999999999998],
#  [191.0, 95.0, 0.49738219895287961],
#  [193.0, 80.0, 0.41450777202072536],
#  [191.0, 94.0, 0.49214659685863876],
#  [183.0, 79.0, 0.43169398907103823],
#  [190.0, 96.0, 0.50526315789473686],
#  [191.0, 85.0, 0.44502617801047123]]

# %%
player = 'James Harden'
train_df = train_players_df[player]
train_df[train_df.SHOT_MADE_FLAG==1]
# Out:
#        PLAYER_ID   PLAYER_NAME     TEAM_ID        TEAM_NAME  \
# 52471     201935  James Harden  1610612745  Houston Rockets
# 51098     201935  James Harden  1610612745  Houston Rockets
# 52383     201935  James Harden  1610612745  Houston Rockets
# 51221     201935  James Harden  1610612745  Houston Rockets
# 51159     201935  James Harden  1610612745  Houston Rockets
# 51225     201935  James Harden  1610612745  Houston Rockets
# 52021     201935  James Harden  1610612745  Houston Rockets
# 51986     201935  James Harden  1610612745  Houston Rockets
# 51785     201935  James Harden  1610612745  Houston Rockets
# 52435     201935  James Harden  1610612745  Houston Rockets
# 51407     201935  James Harden  1610612745  Houston Rockets
# 52130     201935  James Harden  1610612745  Houston Rockets
# 51958     201935  James Harden  1610612745  Houston Rockets
# 52313     201935  James Harden  1610612745  Houston Rockets
# 51071     201935  James Harden  1610612745  Houston Rockets
# 52086     201935  James Harden  1610612745  Houston Rockets
# 52575     201935  James Harden  1610612745  Houston Rockets
# 51742     201935  James Harden  1610612745  Houston Rockets
# 52542     201935  James Harden  1610612745  Houston Rockets
# 51486     201935  James Harden  1610612745  Houston Rockets
# 52274     201935  James Harden  1610612745  Houston Rockets
# 52623     201935  James Harden  1610612745  Houston Rockets
# 52345     201935  James Harden  1610612745  Houston Rockets
# 51693     201935  James Harden  1610612745  Houston Rockets
# 51264     201935  James Harden  1610612745  Houston Rockets
# 52411     201935  James Harden  1610612745  Houston Rockets
# 52047     201935  James Harden  1610612745  Houston Rockets
# 51082     201935  James Harden  1610612745  Houston Rockets
# 51459     201935  James Harden  1610612745  Houston Rockets
# 52576     201935  James Harden  1610612745  Houston Rockets
# ...          ...           ...         ...              ...
# 52495     201935  James Harden  1610612745  Houston Rockets
# 52213     201935  James Harden  1610612745  Houston Rockets
# 51471     201935  James Harden  1610612745  Houston Rockets
# 51764     201935  James Harden  1610612745  Houston Rockets
# 52096     201935  James Harden  1610612745  Houston Rockets
# 51792     201935  James Harden  1610612745  Houston Rockets
# 52582     201935  James Harden  1610612745  Houston Rockets
# 51496     201935  James Harden  1610612745  Houston Rockets
# 52366     201935  James Harden  1610612745  Houston Rockets
# 51926     201935  James Harden  1610612745  Houston Rockets
# 52258     201935  James Harden  1610612745  Houston Rockets
# 52187     201935  James Harden  1610612745  Houston Rockets
# 51817     201935  James Harden  1610612745  Houston Rockets
# 51803     201935  James Harden  1610612745  Houston Rockets
# 51900     201935  James Harden  1610612745  Houston Rockets
# 51733     201935  James Harden  1610612745  Houston Rockets
# 52229     201935  James Harden  1610612745  Houston Rockets
# 52611     201935  James Harden  1610612745  Houston Rockets
# 51124     201935  James Harden  1610612745  Houston Rockets
# 51121     201935  James Harden  1610612745  Houston Rockets
# 51998     201935  James Harden  1610612745  Houston Rockets
# 51363     201935  James Harden  1610612745  Houston Rockets
# 52204     201935  James Harden  1610612745  Houston Rockets
# 51343     201935  James Harden  1610612745  Houston Rockets
# 51170     201935  James Harden  1610612745  Houston Rockets
# 51919     201935  James Harden  1610612745  Houston Rockets
# 51536     201935  James Harden  1610612745  Houston Rockets
# 51779     201935  James Harden  1610612745  Houston Rockets
# 51518     201935  James Harden  1610612745  Houston Rockets
# 52009     201935  James Harden  1610612745  Houston Rockets
#
#                           ACTION_TYPE  SHOT_DISTANCE       SHOT_TYPE  LOC_X  \
# 52471                       Jump Shot             23  3PT Field Goal    159
# 51098                       Jump Shot             25  3PT Field Goal   -153
# 52383                      Layup Shot              1  2PT Field Goal      9
# 51221                Pullup Jump shot             25  3PT Field Goal     -1
# 51159              Driving Layup Shot              3  2PT Field Goal     14
# 51225              Driving Layup Shot              2  2PT Field Goal    -22
# 52021                       Jump Shot             26  3PT Field Goal     82
# 51986                       Jump Shot             25  3PT Field Goal    205
# 51785              Driving Layup Shot              1  2PT Field Goal    -19
# 52435  Cutting Finger Roll Layup Shot              1  2PT Field Goal    -11
# 51407                       Jump Shot             25  3PT Field Goal   -205
# 52130                       Jump Shot             25  3PT Field Goal   -214
# 51958             Step Back Jump shot             25  3PT Field Goal    163
# 52313  Running Finger Roll Layup Shot              1  2PT Field Goal      9
# 51071              Driving Layup Shot              2  2PT Field Goal    -20
# 52086              Fadeaway Jump Shot             16  2PT Field Goal    156
# 52575                Pullup Jump shot             27  3PT Field Goal    169
# 51742                Pullup Jump shot             14  2PT Field Goal    -37
# 52542              Driving Layup Shot              2  2PT Field Goal    -24
# 51486              Cutting Layup Shot              0  2PT Field Goal      6
# 52274                       Jump Shot             13  2PT Field Goal     10
# 52623              Driving Layup Shot              2  2PT Field Goal    -22
# 52345             Step Back Jump shot             14  2PT Field Goal    127
# 51693                       Jump Shot             24  3PT Field Goal    151
# 51264              Driving Layup Shot              2  2PT Field Goal    -27
# 52411  Running Finger Roll Layup Shot              2  2PT Field Goal     -6
# 52047             Step Back Jump shot             14  2PT Field Goal   -145
# 51082              Driving Layup Shot              1  2PT Field Goal    -16
# 51459                  Tip Layup Shot              2  2PT Field Goal    -22
# 52576                Pullup Jump shot             26  3PT Field Goal   -114
# ...                               ...            ...             ...    ...
# 52495              Running Layup Shot              1  2PT Field Goal    -14
# 52213              Driving Layup Shot              0  2PT Field Goal     -1
# 51471        Turnaround Fadeaway shot             18  2PT Field Goal    138
# 51764              Driving Layup Shot              2  2PT Field Goal    -20
# 52096              Driving Layup Shot              2  2PT Field Goal     -1
# 51792             Step Back Jump shot             16  2PT Field Goal     50
# 52582                Pullup Jump shot             28  3PT Field Goal   -109
# 51496              Running Layup Shot              2  2PT Field Goal     25
# 52366       Running Pull-Up Jump Shot             24  3PT Field Goal     79
# 51926                      Layup Shot              0  2PT Field Goal     -4
# 52258             Step Back Jump shot             15  2PT Field Goal    122
# 52187              Running Layup Shot              1  2PT Field Goal     -9
# 51817                       Jump Shot              4  2PT Field Goal    -27
# 51803              Running Layup Shot              1  2PT Field Goal    -14
# 51900                       Jump Shot             25  3PT Field Goal     87
# 51733                      Layup Shot              0  2PT Field Goal      9
# 52229  Running Finger Roll Layup Shot              1  2PT Field Goal     -7
# 52611              Running Layup Shot              1  2PT Field Goal    -19
# 51124                      Layup Shot              2  2PT Field Goal    -16
# 51121                       Jump Shot              7  2PT Field Goal     76
# 51998                       Jump Shot             11  2PT Field Goal    -60
# 51363              Driving Layup Shot              1  2PT Field Goal    -11
# 52204              Fadeaway Jump Shot             11  2PT Field Goal     56
# 51343                Pullup Jump shot             24  3PT Field Goal    156
# 51170              Cutting Layup Shot              2  2PT Field Goal    -16
# 51919  Driving Finger Roll Layup Shot              1  2PT Field Goal     15
# 51536              Driving Layup Shot              2  2PT Field Goal    -19
# 51779                       Jump Shot             25  3PT Field Goal    -45
# 51518              Running Layup Shot              1  2PT Field Goal    -12
# 52009                       Jump Shot             24  3PT Field Goal    135
#
#        LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG
# 52471    178                    1               1
# 51098    200                    1               1
# 52383      8                    1               1
# 51221    257                    1               1
# 51159     31                    1               1
# 51225      0                    1               1
# 52021    247                    1               1
# 51986    159                    1               1
# 51785     -1                    1               1
# 52435      2                    1               1
# 51407    149                    1               1
# 52130    146                    1               1
# 51958    193                    1               1
# 52313     11                    1               1
# 51071      7                    1               1
# 52086     46                    1               1
# 52575    213                    1               1
# 51742    144                    1               1
# 52542     -5                    1               1
# 51486     -1                    1               1
# 52274    134                    1               1
# 52623      0                    1               1
# 52345     77                    1               1
# 51693    195                    1               1
# 51264     -1                    1               1
# 52411     21                    1               1
# 52047     18                    1               1
# 51082     11                    1               1
# 51459     -1                    1               1
# 52576    234                    1               1
# ...      ...                  ...             ...
# 52495     -5                    1               1
# 52213      3                    1               1
# 51471    129                    1               1
# 51764      3                    1               1
# 52096     23                    1               1
# 51792    159                    1               1
# 52582    262                    1               1
# 51496      7                    1               1
# 52366    234                    1               1
# 51926      8                    1               1
# 52258     95                    1               1
# 52187    -10                    1               1
# 51817     36                    1               1
# 51803     11                    1               1
# 51900    237                    1               1
# 51733     -1                    1               1
# 52229     18                    1               1
# 52611      2                    1               1
# 51124     16                    1               1
# 51121     11                    1               1
# 51998     95                    1               1
# 51363      7                    1               1
# 52204    101                    1               1
# 51343    195                    1               1
# 51170     16                    1               1
# 51919      8                    1               1
# 51536      7                    1               1
# 51779    247                    1               1
# 51518     -1                    1               1
# 52009    203                    1               1
#
# [567 rows x 11 columns]
